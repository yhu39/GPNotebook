# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from gpnotebook.tools.standard_imports import *

# %%
cancers = cptac_glyco.get_cancer_info()
cancers
# Out:
# {'brca': 'Breast invasive carcinoma',
#  'ccrcc': 'Clear cell renal cell carcinoma',
#  'coad': 'Colon adenocarcinoma',
#  'gbm': 'Glioblastoma multiforme',
#  'hnscc': 'Head and Neck squamous cell carcinoma',
#  'lscc': 'Lung squamous cell carcinoma',
#  'luad': 'Lung adenocarcinoma',
#  'ov': 'Ovarian serous cystadenocarcinoma',
#  'pdac': 'Pancreatic ductal adenocarcinoma',
#  'ucec': 'Uterine Corpus Endometrial Carcinoma'}

# %%
glycoproteins = []
glycopeptides = []

for cancer in cancers:
    cancer_glyco = cptac_glyco.get_cancer(cancer).get_glycoproteomics()
    for index,row in cancer_glyco.iterrows():
        glycopeptide = '@'.join([str(i) for i in index])
        glycoprotein = index[0]
        glycopeptides.append(glycopeptide)
        glycoproteins.append(glycoprotein)

print(len(set(glycopeptides)),len(set(glycoproteins)))
# Out:
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/brca/glycoproteomics_abundance.joblib
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/ccrcc/glycoproteomics_abundance.joblib
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/coad/glycoproteomics_abundance.joblib
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/gbm/glycoproteomics_abundance.joblib
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/hnscc/glycoproteomics_abundance.joblib
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/lscc/glycoproteomics_abundance.joblib
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/luad/glycoproteomics_abundance.joblib
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/ov/glycoproteomics_abundance.joblib
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/pdac/glycoproteomics_abundance.joblib
# /Users/yingweihu/Documents/GitHub/cptac_glyco/cptac_glyco/ucec/glycoproteomics_abundance.joblib
# 90661 2194

# %%
cancer_glyco.head(2)
# Out:
#                                                                                  Intensity.Reference  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0            12.904211
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0            15.554518
#
#                                                                                  BRC.11BR047.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0      13.450475
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      17.426269
#
#                                                                                  BRC.11BR043.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0      10.901705
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      15.361372
#
#                                                                                  BRC.11BR049.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0            NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      14.549526
#
#                                                                                  BRC.11BR023.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0      12.566296
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      16.753951
#
#                                                                                  BRC.18BR010.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0      11.550257
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      13.789209
#
#                                                                                  BRC.06BR003.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0            NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      12.955426
#
#                                                                                  BRC.11BR074.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0      10.927501
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      15.751797
#
#                                                                                  BRC.18BR017.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0      12.471891
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      15.460068
#
#                                                                                  BRC.01BR017.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0       3.570037
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      14.656370
#
#                                                                                  ...  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan      ...
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0  ...
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0  ...
#
#                                                                                  BRC.01BR023.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0            NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      16.032072
#
#                                                                                  BRC.11BR011.T - set 17 127N  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0                          NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0                    16.189691
#
#                                                                                  BRC.01BR020.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0            NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0       15.78947
#
#                                                                                  BRC.20BR006.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0            NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      16.044418
#
#                                                                                  BRC.21BR010.T - set 17 128C  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0                          NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0                    16.115047
#
#                                                                                  BRC.09BR001.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0            NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      15.293661
#
#                                                                                  BRC.03BR011.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0            NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      14.801998
#
#                                                                                  BRC.11BR036.T - set 17 130N  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0                          NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0                    16.965771
#
#                                                                                  BRC.01BR010.T  \
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0            NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0      14.132177
#
#                                                                                  BRC.Reference Sample 17
# Gene                     Protein           Glycosite Glycopeptide    Glycan
# LAMP1|ENSG00000185896.11 ENSP00000333298.4 249       KDNTTVTR        N4H5F1S2G0                      NaN
# ORM2|ENSG00000228278.4   ENSP00000394936.2 93        QNQCFYNSSYLNVQR N5H6F0S3G0                15.554518
#
# [2 rows x 171 columns]
