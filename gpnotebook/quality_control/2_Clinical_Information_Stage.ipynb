# %% [markdown]
# # 1. Import essential packages

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from gpnotebook.tools.standard_imports import *

# %% [markdown]
# # 2. Download clinical information for all cancer types

# %%
feature = 'tumor_stage_pathological'

from gpnotebook.tools.clinical import summarize_feature, get_all_simplified_feature_names

feature_names = get_all_simplified_feature_names(feature)
feature_table = summarize_feature(feature)

# %%
from gpnotebook.tools.visualization import stacked_bar_plot

colors = list(zip(feature_names,['r','b','g','orange','grey']))
fig = stacked_bar_plot(feature_table,feature_names,colors,title=featur
