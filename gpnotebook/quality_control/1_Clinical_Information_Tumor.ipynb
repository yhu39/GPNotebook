# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from gpnotebook.tools.standard_imports import *

# %%
feature = 'type_of_anlayzed_samples'

from gpnotebook.tools.clinical import summarize_feature

# %%
feature_table = summarize_feature(feature)
# Out:
# brca
# ccrcc
# coad
# gbm
# hnscc
# lscc
# luad
# ov
# pdac
# ucec

# %%
feature_table
# Out:
#        Tumor  Normal  Patients
# BRCA     122       0       125
# CCRCC    103      80       110
# COAD      97     100       101
# GBM       99      10       110
# HNSCC    108      66       112
# LSCC     108      99       110
# LUAD     110     101       111
# OV        83      23        95
# PDAC     140      75       153
# UCEC      95      49       122

# %%
from gpnotebook.tools.visualization import split_bar_plot

fig = split_bar_plot(feature_table)
